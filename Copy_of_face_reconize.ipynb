# %%
import cv2
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from google.colab.patches import cv2_imshow
import cv2
img=cv2.imread('/content/face.jpeg')
print(cv2_imshow(img))
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>
# None

# %%
img
# Out:
# array([[[39, 31, 31],
#         [39, 31, 31],
#         [39, 31, 31],
#         ...,
#         [32, 28, 33],
#         [30, 27, 29],
#         [29, 30, 28]],
#
#        [[39, 31, 31],
#         [39, 31, 31],
#         [39, 31, 31],
#         ...,
#         [32, 28, 33],
#         [30, 27, 29],
#         [29, 30, 28]],
#
#        [[39, 31, 31],
#         [39, 31, 31],
#         [39, 31, 31],
#         ...,
#         [33, 29, 34],
#         [30, 27, 29],
#         [29, 29, 29]],
#
#        ...,
#
#        [[28, 28, 34],
#         [28, 28, 34],
#         [29, 29, 35],
#         ...,
#         [44, 47, 68],
#         [44, 47, 68],
#         [43, 46, 67]],
#
#        [[28, 28, 34],
#         [26, 29, 34],
#         [29, 29, 35],
#         ...,
#         [43, 46, 67],
#         [43, 46, 67],
#         [42, 45, 66]],
#
#        [[27, 30, 35],
#         [26, 30, 35],
#         [27, 30, 35],
#         ...,
#         [41, 45, 64],
#         [42, 46, 65],
#         [41, 45, 64]]], dtype=uint8)

# %%
img.shape
# Out:
# (225, 225, 3)

# %%
img3=cv2.imread('/content/face.jpeg',0)
print(cv2_imshow(img3))
# Out:
# <PIL.Image.Image image mode=L size=225x225>
# None

# %%
img3.shape
# Out:
# (225, 225)

# %%
img2=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
print(cv2_imshow(img2))
# Out:
# <PIL.Image.Image image mode=L size=225x225>
# None

# %%
#convert image to hsv format
new_image=cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
cv2_imshow(new_image)
# hsv to understand the color intensity correctly
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
new_image.shape
# Out:
# (225, 225, 3)

# %%
new_image
# Out:
# array([[[120,  52,  39],
#         [120,  52,  39],
#         [120,  52,  39],
#         ...,
#         [156,  39,  33],
#         [140,  26,  30],
#         [ 75,  17,  30]],
#
#        [[120,  52,  39],
#         [120,  52,  39],
#         [120,  52,  39],
#         ...,
#         [156,  39,  33],
#         [140,  26,  30],
#         [ 75,  17,  30]],
#
#        [[120,  52,  39],
#         [120,  52,  39],
#         [120,  52,  39],
#         ...,
#         [156,  38,  34],
#         [140,  26,  30],
#         [  0,   0,  29]],
#
#        ...,
#
#        [[  0,  45,  34],
#         [  0,  45,  34],
#         [  0,  44,  35],
#         ...,
#         [  4,  90,  68],
#         [  4,  90,  68],
#         [  4,  91,  67]],
#
#        [[  0,  45,  34],
#         [ 11,  60,  34],
#         [  0,  44,  35],
#         ...,
#         [  4,  91,  67],
#         [  4,  91,  67],
#         [  4,  93,  66]],
#
#        [[ 11,  58,  35],
#         [ 13,  66,  35],
#         [ 11,  58,  35],
# ...

# %%
small=cv2.resize(img,(150,100))#.resize function is used to resize
cv2_imshow(small)
# Out:
# <PIL.Image.Image image mode=RGB size=150x100>

# %%
#haarcascade:class of ml algorithm  object detection model if we want to dectec eye,face etc
# already model is train
face_cascade=cv2.CascadeClassifier('/content/opencv_data_haarcascades_haarcascade_frontalface_default.xml ')

# %%
faces=face_cascade.detectMultiScale(img3,1.1,4)
#draw rectangle around face
for(x,y,w,h)in faces:
  cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
  #display output
  cv2_imshow(img)
  cv2.waitKey()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-23-f05838cd7d52> in <cell line: 1>()
# ----> 1 faces=face_cascade.detectMultiScale(img3,1.1,4)
#       2 #draw rectangle around face
#       3 for(x,y,w,h)in faces:
#       4   cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
#       5   #display output
#
# error: OpenCV(4.8.0) /io/opencv/modules/objdetect/src/cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'detectMultiScale'
